# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



#enumerate() method gets the index of the city for logging purposes and the city for creating an endpoint URL

# Loop through all the cities in our list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description= city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country":city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
   
    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | itarema
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | dvinskoy
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | kaeo
# Processing Record 13 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | bukachacha
# Processing Record 18 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 1 | lavrentiya
# Processing Record 20 of Set 1 | phan thiet
# Processing Record 21 of Set 1 | qaqortoq
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | fukue
# Processing Record 24 of Set 1 | caluquembe
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | nichinan
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | katsuura
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | bonham
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | ardalstangen
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | lebu
# Processing Record 35 of Set 1 | dolores
# Processing Record 36 of Set 1 | tigil
# Processing Record 37 of Set 1 | lorengau
# Processing Record 38 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 1 | pangnirtung
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 1 | linhai
# Processing Record 46 of Set 1 | pathein
# Processing Record 47 of Set 1 | ginda
# Processing Record 48 of Set 1 | juneau
# Processing Record 49 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | tyup
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | turukhansk
# Processing Record 6 of Set 2 | airai
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | hambantota
# Processing Record 9 of Set 2 | puerto escondido
# Processing Record 10 of Set 2 | mezen
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | sete
# Processing Record 13 of Set 2 | awjilah
# Processing Record 14 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | sile
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 2 | fort-shevchenko
# Processing Record 22 of Set 2 | atambua
# Processing Record 23 of Set 2 | chapais
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | shwebo
# Processing Record 26 of Set 2 | imeni poliny osipenko
# Processing Record 27 of Set 2 | hami
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | banjar
# Processing Record 30 of Set 2 | fortuna
# Processing Record 31 of Set 2 | souillac
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | mandera
# Processing Record 34 of Set 2 | nikolskoye
# Processing Record 35 of Set 2 | vyartsilya
# Processing Record 36 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 2 | baikunthpur
# Processing Record 38 of Set 2 | dali
# Processing Record 39 of Set 2 | herat
# Processing Record 40 of Set 2 | middelburg
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | mitsamiouli
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | jiangyou
# Processing Record 45 of Set 2 | camacha
# Processing Record 46 of Set 2 | severnyy
# Processing Record 47 of Set 2 | najran
# Processing Record 48 of Set 2 | avera
# Processing Record 49 of Set 2 | svetlogorsk
# Processing Record 50 of Set 2 | atar
# Processing Record 1 of Set 3 | athabasca
# Processing Record 2 of Set 3 | maloy
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | viedma
# Processing Record 5 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 3 | cam ranh
# Processing Record 7 of Set 3 | kirakira
# Processing Record 8 of Set 3 | high level
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | buraydah
# Processing Record 11 of Set 3 | ribeira grande
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | port hardy
# Processing Record 14 of Set 3 | upernavik
# Processing Record 15 of Set 3 | tazovskiy
# Processing Record 16 of Set 3 | thompson
# Processing Record 17 of Set 3 | ponta do sol
# Processing Record 18 of Set 3 | kalmunai
# Processing Record 19 of Set 3 | caravelas
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | tiksi
# Processing Record 22 of Set 3 | karratha
# Processing Record 23 of Set 3 | sao felix do xingu
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | mogadishu
# Processing Record 26 of Set 3 | poum
# Processing Record 27 of Set 3 | dalianwan
# Processing Record 28 of Set 3 | xixiang
# Processing Record 29 of Set 3 | sitka
# Processing Record 30 of Set 3 | kayes
# Processing Record 31 of Set 3 | nikolayevsk-na-amure
# Processing Record 32 of Set 3 | salinopolis
# Processing Record 33 of Set 3 | aguimes
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | alofi
# Processing Record 36 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 37 of Set 3 | hithadhoo
# Processing Record 38 of Set 3 | hastings
# Processing Record 39 of Set 3 | floro
# Processing Record 40 of Set 3 | port macquarie
# Processing Record 41 of Set 3 | mangochi
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | muros
# Processing Record 44 of Set 3 | chulym
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | havoysund
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | henties bay
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | kafanchan
# Processing Record 1 of Set 4 | dunedin
# Processing Record 2 of Set 4 | manaure
# Processing Record 3 of Set 4 | bambanglipuro
# Processing Record 4 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 5 of Set 4 | hofn
# Processing Record 6 of Set 4 | vrangel
# Processing Record 7 of Set 4 | sorland
# Processing Record 8 of Set 4 | aztec
# Processing Record 9 of Set 4 | nizhniy kuranakh
# Processing Record 10 of Set 4 | pimentel
# Processing Record 11 of Set 4 | evensk
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | burica
# City not found. Skipping...
# Processing Record 14 of Set 4 | dingle
# Processing Record 15 of Set 4 | nishihara
# Processing Record 16 of Set 4 | clonakilty
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | raga
# Processing Record 19 of Set 4 | sawtell
# Processing Record 20 of Set 4 | minot
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | spencer
# Processing Record 23 of Set 4 | sechura
# Processing Record 24 of Set 4 | bodden town
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | walvis bay
# Processing Record 27 of Set 4 | cockburn town
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | mon
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | kodiak
# Processing Record 34 of Set 4 | stavanger
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | hit
# Processing Record 37 of Set 4 | rehoboth
# Processing Record 38 of Set 4 | rosarito
# Processing Record 39 of Set 4 | saskylakh
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | koutsouras
# Processing Record 42 of Set 4 | inhambane
# Processing Record 43 of Set 4 | champerico
# Processing Record 44 of Set 4 | mahebourg
# Processing Record 45 of Set 4 | zhezkazgan
# Processing Record 46 of Set 4 | suao
# City not found. Skipping...
# Processing Record 47 of Set 4 | westport
# Processing Record 48 of Set 4 | bonavista
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | tsnori
# Processing Record 1 of Set 5 | wattegama
# Processing Record 2 of Set 5 | hilo
# Processing Record 3 of Set 5 | coihaique
# Processing Record 4 of Set 5 | bossangoa
# Processing Record 5 of Set 5 | saint george
# Processing Record 6 of Set 5 | merauke
# Processing Record 7 of Set 5 | mariana
# Processing Record 8 of Set 5 | los llanos de aridane
# Processing Record 9 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | ingham
# Processing Record 13 of Set 5 | lashio
# Processing Record 14 of Set 5 | mayumba
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | tuatapere
# Processing Record 17 of Set 5 | georgetown
# Processing Record 18 of Set 5 | gafanha da encarnacao
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | diapaga
# Processing Record 22 of Set 5 | tugulym
# Processing Record 23 of Set 5 | belokurikha
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | delano
# Processing Record 29 of Set 5 | abha
# Processing Record 30 of Set 5 | udachnyy
# Processing Record 31 of Set 5 | ketchikan
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | lobito
# Processing Record 34 of Set 5 | itinga
# Processing Record 35 of Set 5 | binzhou
# Processing Record 36 of Set 5 | klaksvik
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | nenjiang
# Processing Record 39 of Set 5 | yar-sale
# Processing Record 40 of Set 5 | ouadda
# Processing Record 41 of Set 5 | bathsheba
# Processing Record 42 of Set 5 | labuhan
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | vostok
# Processing Record 45 of Set 5 | tasiilaq
# Processing Record 46 of Set 5 | sao jose da coroa grande
# Processing Record 47 of Set 5 | tuktoyaktuk
# Processing Record 48 of Set 5 | stabat
# Processing Record 49 of Set 5 | barentu
# Processing Record 50 of Set 5 | bocas del toro
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | san carlos de bariloche
# Processing Record 3 of Set 6 | serra
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | tabas
# Processing Record 6 of Set 6 | ostersund
# Processing Record 7 of Set 6 | kununurra
# Processing Record 8 of Set 6 | port augusta
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | sao joao da barra
# Processing Record 12 of Set 6 | boa vista
# Processing Record 13 of Set 6 | ishigaki
# Processing Record 14 of Set 6 | bambari
# Processing Record 15 of Set 6 | balikpapan
# Processing Record 16 of Set 6 | neiafu
# Processing Record 17 of Set 6 | yerbogachen
# Processing Record 18 of Set 6 | palmer
# Processing Record 19 of Set 6 | sukabumi
# Processing Record 20 of Set 6 | manyana
# Processing Record 21 of Set 6 | dukat
# Processing Record 22 of Set 6 | hobyo
# Processing Record 23 of Set 6 | swan hill
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | bethel
# Processing Record 26 of Set 6 | luderitz
# Processing Record 27 of Set 6 | zhigansk
# Processing Record 28 of Set 6 | shenjiamen
# Processing Record 29 of Set 6 | jardim
# Processing Record 30 of Set 6 | makakilo city
# Processing Record 31 of Set 6 | mogochin
# City not found. Skipping...
# Processing Record 32 of Set 6 | skeldon
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | shemysheyka
# Processing Record 35 of Set 6 | idil
# Processing Record 36 of Set 6 | sakaiminato
# Processing Record 37 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 6 | balsas
# Processing Record 39 of Set 6 | necocli
# Processing Record 40 of Set 6 | tanah merah
# Processing Record 41 of Set 6 | bagan
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | saint-francois
# Processing Record 44 of Set 6 | phnum penh
# City not found. Skipping...
# Processing Record 45 of Set 6 | ilulissat
# Processing Record 46 of Set 6 | muzhi
# Processing Record 47 of Set 6 | fairlie
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | salalah
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | havelock
# Processing Record 3 of Set 7 | porto novo
# Processing Record 4 of Set 7 | rawson
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | saint-augustin
# Processing Record 7 of Set 7 | victor harbor
# Processing Record 8 of Set 7 | maniitsoq
# Processing Record 9 of Set 7 | loandjili
# Processing Record 10 of Set 7 | bardiyah
# Processing Record 11 of Set 7 | boddam
# Processing Record 12 of Set 7 | kargopol
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | la rioja
# Processing Record 15 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 7 | barcelos
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | villacarrillo
# Processing Record 20 of Set 7 | muisne
# Processing Record 21 of Set 7 | kavieng
# Processing Record 22 of Set 7 | ostrovnoy
# Processing Record 23 of Set 7 | sabang
# Processing Record 24 of Set 7 | sao gabriel da cachoeira
# Processing Record 25 of Set 7 | catabola
# Processing Record 26 of Set 7 | carballo
# Processing Record 27 of Set 7 | sibu
# Processing Record 28 of Set 7 | san-pedro
# Processing Record 29 of Set 7 | fort nelson
# Processing Record 30 of Set 7 | haripur
# Processing Record 31 of Set 7 | waipawa
# Processing Record 32 of Set 7 | ahipara
# Processing Record 33 of Set 7 | madarounfa
# Processing Record 34 of Set 7 | kandi
# Processing Record 35 of Set 7 | moose factory
# Processing Record 36 of Set 7 | visnes
# Processing Record 37 of Set 7 | cap malheureux
# Processing Record 38 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 7 | matamoros
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | general roca
# Processing Record 42 of Set 7 | marzuq
# Processing Record 43 of Set 7 | brookhaven
# Processing Record 44 of Set 7 | tromso
# Processing Record 45 of Set 7 | panama city
# Processing Record 46 of Set 7 | todos santos
# Processing Record 47 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | harper
# Processing Record 49 of Set 7 | hualmay
# Processing Record 50 of Set 7 | la palma
# Processing Record 1 of Set 8 | mizdah
# Processing Record 2 of Set 8 | bay roberts
# Processing Record 3 of Set 8 | ejura
# Processing Record 4 of Set 8 | wewak
# Processing Record 5 of Set 8 | korla
# Processing Record 6 of Set 8 | acapulco
# Processing Record 7 of Set 8 | ilanskiy
# Processing Record 8 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 9 of Set 8 | saint-philippe
# Processing Record 10 of Set 8 | sabha
# Processing Record 11 of Set 8 | pedasi
# Processing Record 12 of Set 8 | brotas
# Processing Record 13 of Set 8 | longyearbyen
# Processing Record 14 of Set 8 | kasempa
# Processing Record 15 of Set 8 | huaicheng
# Processing Record 16 of Set 8 | murgab
# Processing Record 17 of Set 8 | te anau
# Processing Record 18 of Set 8 | ranong
# Processing Record 19 of Set 8 | kruisfontein
# Processing Record 20 of Set 8 | zwedru
# Processing Record 21 of Set 8 | trairi
# Processing Record 22 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 23 of Set 8 | grootfontein
# Processing Record 24 of Set 8 | kaa-khem
# Processing Record 25 of Set 8 | kajaani
# Processing Record 26 of Set 8 | yongzhou
# Processing Record 27 of Set 8 | abu road
# Processing Record 28 of Set 8 | west wendover
# Processing Record 29 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 30 of Set 8 | namatanai
# Processing Record 31 of Set 8 | santa rosa
# Processing Record 32 of Set 8 | coquimbo
# Processing Record 33 of Set 8 | colac
# Processing Record 34 of Set 8 | bugiri
# Processing Record 35 of Set 8 | bolshaya irba
# City not found. Skipping...
# Processing Record 36 of Set 8 | manokwari
# Processing Record 37 of Set 8 | sinnamary
# Processing Record 38 of Set 8 | ust-kut
# Processing Record 39 of Set 8 | mizoch
# Processing Record 40 of Set 8 | roald
# Processing Record 41 of Set 8 | manama
# Processing Record 42 of Set 8 | salekhard
# Processing Record 43 of Set 8 | bubanza
# Processing Record 44 of Set 8 | otane
# Processing Record 45 of Set 8 | ongandjera
# Processing Record 46 of Set 8 | xuddur
# Processing Record 47 of Set 8 | fujin
# Processing Record 48 of Set 8 | rio tuba
# Processing Record 49 of Set 8 | kattivakkam
# Processing Record 50 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 1 of Set 9 | black diamond
# Processing Record 2 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 9 | cabra
# Processing Record 4 of Set 9 | kortkeros
# Processing Record 5 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 6 of Set 9 | barra do garcas
# Processing Record 7 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 9 | grand gaube
# Processing Record 9 of Set 9 | mayo
# Processing Record 10 of Set 9 | khonsa
# Processing Record 11 of Set 9 | luganville
# Processing Record 12 of Set 9 | khandyga
# Processing Record 13 of Set 9 | romny
# Processing Record 14 of Set 9 | lanivtsi
# Processing Record 15 of Set 9 | oktyabrskiy
# Processing Record 16 of Set 9 | cherskiy
# Processing Record 17 of Set 9 | norman wells
# Processing Record 18 of Set 9 | katobu
# Processing Record 19 of Set 9 | omboue
# Processing Record 20 of Set 9 | fergus falls
# Processing Record 21 of Set 9 | tosham
# Processing Record 22 of Set 9 | kauhajoki
# Processing Record 23 of Set 9 | tomatlan
# Processing Record 24 of Set 9 | clyde river
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | adrar
# Processing Record 27 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 9 | lagoa
# Processing Record 29 of Set 9 | colares
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | ambulu
# Processing Record 32 of Set 9 | antalaha
# Processing Record 33 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 9 | flinders
# Processing Record 35 of Set 9 | palasa
# Processing Record 36 of Set 9 | dwarka
# Processing Record 37 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 9 | kourou
# Processing Record 39 of Set 9 | shirokiy
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | santa isabel do rio negro
# Processing Record 42 of Set 9 | yankton
# Processing Record 43 of Set 9 | amapa
# Processing Record 44 of Set 9 | mount gambier
# Processing Record 45 of Set 9 | dothan
# Processing Record 46 of Set 9 | nsanje
# Processing Record 47 of Set 9 | sanary-sur-mer
# Processing Record 48 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 9 | asau
# Processing Record 50 of Set 9 | buchanan
# Processing Record 1 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 2 of Set 10 | aitape
# Processing Record 3 of Set 10 | zhanatas
# City not found. Skipping...
# Processing Record 4 of Set 10 | ahuimanu
# Processing Record 5 of Set 10 | hay river
# Processing Record 6 of Set 10 | guerrero negro
# Processing Record 7 of Set 10 | diamantino
# Processing Record 8 of Set 10 | novopokrovka
# Processing Record 9 of Set 10 | acajutla
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | matara
# Processing Record 12 of Set 10 | nadym
# Processing Record 13 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 10 | yinchuan
# Processing Record 15 of Set 10 | kuching
# Processing Record 16 of Set 10 | charters towers
# Processing Record 17 of Set 10 | san vicente
# Processing Record 18 of Set 10 | puerto leguizamo
# Processing Record 19 of Set 10 | mbarara
# Processing Record 20 of Set 10 | stephenville
# Processing Record 21 of Set 10 | greytown
# Processing Record 22 of Set 10 | hohhot
# Processing Record 23 of Set 10 | merrill
# Processing Record 24 of Set 10 | alegrete
# Processing Record 25 of Set 10 | hope
# Processing Record 26 of Set 10 | dalbandin
# Processing Record 27 of Set 10 | vestmannaeyjar
# Processing Record 28 of Set 10 | vila
# Processing Record 29 of Set 10 | gat
# Processing Record 30 of Set 10 | yenagoa
# Processing Record 31 of Set 10 | axim
# Processing Record 32 of Set 10 | lerwick
# Processing Record 33 of Set 10 | ostashkov
# Processing Record 34 of Set 10 | general pico
# Processing Record 35 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 36 of Set 10 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 37 of Set 10 | tual
# Processing Record 38 of Set 10 | atbasar
# Processing Record 39 of Set 10 | rio gallegos
# Processing Record 40 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 41 of Set 10 | biak
# Processing Record 42 of Set 10 | rambha
# Processing Record 43 of Set 10 | lokosovo
# Processing Record 44 of Set 10 | mopti
# Processing Record 45 of Set 10 | paamiut
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | sur
# Processing Record 48 of Set 10 | porbandar
# Processing Record 49 of Set 10 | codrington
# Processing Record 50 of Set 10 | kualakapuas
# Processing Record 1 of Set 11 | sorkjosen
# Processing Record 2 of Set 11 | saint anthony
# Processing Record 3 of Set 11 | meridian
# Processing Record 4 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 11 | vila franca do campo
# Processing Record 6 of Set 11 | faya
# Processing Record 7 of Set 11 | portage
# Processing Record 8 of Set 11 | naryan-mar
# Processing Record 9 of Set 11 | gambela
# Processing Record 10 of Set 11 | sistranda
# Processing Record 11 of Set 11 | antofagasta
# Processing Record 12 of Set 11 | belaya gora
# Processing Record 13 of Set 11 | yulin
# Processing Record 14 of Set 11 | feuchtwangen
# Processing Record 15 of Set 11 | abeche
# Processing Record 16 of Set 11 | xingcheng
# Processing Record 17 of Set 11 | fasa
# Processing Record 18 of Set 11 | ulaangom
# Processing Record 19 of Set 11 | veraval
# Processing Record 20 of Set 11 | aykhal
# Processing Record 21 of Set 11 | okhotsk
# Processing Record 22 of Set 11 | esperance
# Processing Record 23 of Set 11 | pombia
# Processing Record 24 of Set 11 | onega
# Processing Record 25 of Set 11 | piacabucu
# Processing Record 26 of Set 11 | alyangula
# Processing Record 27 of Set 11 | saint-paul
# Processing Record 28 of Set 11 | muroto
# Processing Record 29 of Set 11 | olafsvik
# Processing Record 30 of Set 11 | nova olinda do norte
# Processing Record 31 of Set 11 | naron
# Processing Record 32 of Set 11 | vila velha
# Processing Record 33 of Set 11 | kailua
# Processing Record 34 of Set 11 | broome
# Processing Record 35 of Set 11 | jieshi
# Processing Record 36 of Set 11 | gravelbourg
# Processing Record 37 of Set 11 | padang
# Processing Record 38 of Set 11 | adre
# Processing Record 39 of Set 11 | houma
# Processing Record 40 of Set 11 | nijar
# Processing Record 41 of Set 11 | maniwaki
# Processing Record 42 of Set 11 | zalantun
# Processing Record 43 of Set 11 | sterling
# Processing Record 44 of Set 11 | durango
# Processing Record 45 of Set 11 | marawi
# Processing Record 46 of Set 11 | darhan
# Processing Record 47 of Set 11 | hvide sande
# Processing Record 48 of Set 11 | tokur
# Processing Record 49 of Set 11 | tabou
# Processing Record 50 of Set 11 | policoro
# Processing Record 1 of Set 12 | hondo
# Processing Record 2 of Set 12 | virginia beach
# Processing Record 3 of Set 12 | jinchang
# Processing Record 4 of Set 12 | bichura
# Processing Record 5 of Set 12 | gizo
# Processing Record 6 of Set 12 | mollendo
# Processing Record 7 of Set 12 | baoding
# Processing Record 8 of Set 12 | hovd
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | morondava
# Processing Record 11 of Set 12 | tupiza
# Processing Record 12 of Set 12 | xinmin
# Processing Record 13 of Set 12 | meulaboh
# Processing Record 14 of Set 12 | san quintin
# Processing Record 15 of Set 12 | doka
# Processing Record 16 of Set 12 | hengyang
# Processing Record 17 of Set 12 | saint-georges
# Processing Record 18 of Set 12 | cumbum
# Processing Record 19 of Set 12 | itoman
# Processing Record 20 of Set 12 | kuito
# Processing Record 21 of Set 12 | meadow lake
# Processing Record 22 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 12 | camapua
# Processing Record 24 of Set 12 | sydney
# Processing Record 25 of Set 12 | olonets
# Processing Record 26 of Set 12 | kyra
# Processing Record 27 of Set 12 | teknaf
# Processing Record 28 of Set 12 | deer lake
# Processing Record 29 of Set 12 | asfi
# Processing Record 30 of Set 12 | fomboni
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | mogocha
# Processing Record 33 of Set 12 | lao cai
# Processing Record 34 of Set 12 | banda aceh
# Processing Record 35 of Set 12 | kwekwe
# Processing Record 36 of Set 12 | sukheke
# City not found. Skipping...
# Processing Record 37 of Set 12 | aleksandrovskiy zavod
# Processing Record 38 of Set 12 | carutapera
# Processing Record 39 of Set 12 | kjollefjord
# Processing Record 40 of Set 12 | nawabganj
# Processing Record 41 of Set 12 | mareeba
# Processing Record 42 of Set 12 | moerai
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | bara
# Processing Record 45 of Set 12 | buala
# Processing Record 46 of Set 12 | bada
# Processing Record 47 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 12 | magalia
# Processing Record 49 of Set 12 | ashdod
# Processing Record 50 of Set 12 | humberto de campos
# Processing Record 1 of Set 13 | metz
# Processing Record 2 of Set 13 | mulege
# Processing Record 3 of Set 13 | huilong
# Processing Record 4 of Set 13 | teya
# Processing Record 5 of Set 13 | wangqing
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | innisfail
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 10 of Set 13 | kavaratti
# Processing Record 11 of Set 13 | salta
# Processing Record 12 of Set 13 | ji-parana
# City not found. Skipping...
# Processing Record 13 of Set 13 | kijang
# Processing Record 14 of Set 13 | inuvik
# Processing Record 15 of Set 13 | pacific grove
# Processing Record 16 of Set 13 | yabrud
# Processing Record 17 of Set 13 | severo-yeniseyskiy
# Processing Record 18 of Set 13 | suntar
# Processing Record 19 of Set 13 | kotido
# Processing Record 20 of Set 13 | yulara
# Processing Record 21 of Set 13 | dong hoi
# Processing Record 22 of Set 13 | muravlenko
# Processing Record 23 of Set 13 | delta del tigre
# Processing Record 24 of Set 13 | paka
# Processing Record 25 of Set 13 | oistins
# Processing Record 26 of Set 13 | forbes
# Processing Record 27 of Set 13 | chake chake
# Processing Record 28 of Set 13 | ler
# Processing Record 29 of Set 13 | pierre
# Processing Record 30 of Set 13 | chiredzi
# Processing Record 31 of Set 13 | lompoc
# Processing Record 32 of Set 13 | poddorye
# Processing Record 33 of Set 13 | seoul
# Processing Record 34 of Set 13 | yondo
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | nuevo progreso
# Processing Record 37 of Set 13 | smolensk
# Processing Record 38 of Set 13 | borgo san dalmazzo
# Processing Record 39 of Set 13 | ashcroft
# Processing Record 40 of Set 13 | jalu
# Processing Record 41 of Set 13 | matiri
# Processing Record 42 of Set 13 | wanaka
# Processing Record 43 of Set 13 | careiro da varzea
# Processing Record 44 of Set 13 | puerto colombia
# Processing Record 45 of Set 13 | rodos
# Processing Record 46 of Set 13 | katherine
# Processing Record 47 of Set 13 | aswan
# Processing Record 48 of Set 13 | kosya
# City not found. Skipping...
# Processing Record 49 of Set 13 | provideniya
# Processing Record 50 of Set 13 | ugoofaaru
# Processing Record 1 of Set 14 | ucluelet
# Processing Record 2 of Set 14 | auki
# Processing Record 3 of Set 14 | luena
# Processing Record 4 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 14 | khabary
# Processing Record 6 of Set 14 | toyooka
# Processing Record 7 of Set 14 | povenets
# Processing Record 8 of Set 14 | semey
# Processing Record 9 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 14 | kroya
# Processing Record 11 of Set 14 | menongue
# Processing Record 12 of Set 14 | sobolevo
# Processing Record 13 of Set 14 | lachhmangarh
# Processing Record 14 of Set 14 | katha
# City not found. Skipping...
# Processing Record 15 of Set 14 | mastic
# Processing Record 16 of Set 14 | kautokeino
# Processing Record 17 of Set 14 | mormugao
# Processing Record 18 of Set 14 | usinsk
# Processing Record 19 of Set 14 | sigli
# Processing Record 20 of Set 14 | port lincoln
# Processing Record 21 of Set 14 | halifax
# Processing Record 22 of Set 14 | lata
# Processing Record 23 of Set 14 | toba
# Processing Record 24 of Set 14 | cabo rojo
# Processing Record 25 of Set 14 | almeirim
# Processing Record 26 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 14 | krumovgrad
# Processing Record 28 of Set 14 | ulladulla
# Processing Record 29 of Set 14 | maceio
# Processing Record 30 of Set 14 | saint-pierre
# Processing Record 31 of Set 14 | north bend
# Processing Record 32 of Set 14 | keita
# Processing Record 33 of Set 14 | umm lajj
# Processing Record 34 of Set 14 | konce
# Processing Record 35 of Set 14 | pafos
# Processing Record 36 of Set 14 | don sak
# Processing Record 37 of Set 14 | teguise
# Processing Record 38 of Set 14 | kathmandu
# Processing Record 39 of Set 14 | rancho palos verdes
# Processing Record 40 of Set 14 | barranca
# Processing Record 41 of Set 14 | bud
# Processing Record 42 of Set 14 | koumra
# Processing Record 43 of Set 14 | trebinje
# Processing Record 44 of Set 14 | avanigadda
# Processing Record 45 of Set 14 | umm kaddadah
# Processing Record 46 of Set 14 | jaisalmer
# Processing Record 47 of Set 14 | yenotayevka
# Processing Record 48 of Set 14 | yaan
# Processing Record 49 of Set 14 | lasa
# Processing Record 50 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 1 of Set 15 | sotouboua
# Processing Record 2 of Set 15 | lakatoro
# Processing Record 3 of Set 15 | nouadhibou
# Processing Record 4 of Set 15 | ambon
# Processing Record 5 of Set 15 | grindavik
# Processing Record 6 of Set 15 | bilma
# Processing Record 7 of Set 15 | deputatskiy
# Processing Record 8 of Set 15 | ciudad bolivar
# Processing Record 9 of Set 15 | pasighat
# Processing Record 10 of Set 15 | hays
# Processing Record 11 of Set 15 | polovinnoye
# Processing Record 12 of Set 15 | jonkoping
# Processing Record 13 of Set 15 | constantine
# Processing Record 14 of Set 15 | chipinge
# Processing Record 15 of Set 15 | aksarka
# Processing Record 16 of Set 15 | musoma
# Processing Record 17 of Set 15 | mandalgovi
# Processing Record 18 of Set 15 | aksu
# Processing Record 19 of Set 15 | mahibadhoo
# Processing Record 20 of Set 15 | lake city
# Processing Record 21 of Set 15 | shangrao
# Processing Record 22 of Set 15 | neiba
# Processing Record 23 of Set 15 | lixourion
# Processing Record 24 of Set 15 | soto la marina
# Processing Record 25 of Set 15 | riyadh
# Processing Record 26 of Set 15 | tabuk
# Processing Record 27 of Set 15 | deep river
# Processing Record 28 of Set 15 | beihai
# Processing Record 29 of Set 15 | ishinomaki
# Processing Record 30 of Set 15 | sept-iles
# Processing Record 31 of Set 15 | sassandra
# Processing Record 32 of Set 15 | kieta
# Processing Record 33 of Set 15 | karachi
# Processing Record 34 of Set 15 | vagur
# Processing Record 35 of Set 15 | coolum beach
# Processing Record 36 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 15 | tezu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Ushuaia -54.8000  -68.3000     60.46        67          40       14.97
# 1     Albany  42.6001  -73.9662     21.31        76          10        4.18
# 2     Castro -24.7911  -50.0119     61.56        84           2        2.10
# 3    Itarema  -2.9248  -39.9167     78.80        78           2       11.07
# 4     Atuona  -9.8000 -139.0333     78.80        77          12       17.09
# 5   Dvinskoy  62.1535   45.1175     -2.63       100          97        3.91
# 6      Vaini -21.2000 -175.2000     75.36       100         100        4.61
# 7      Pevek  69.7008  170.3133    -23.37        98          27        0.92
# 8  Jamestown  42.0970  -79.2353     29.79        45           0       10.36
# 9    Qaanaaq  77.4840  -69.3632    -11.67        59          29        7.25
#
#   Country          Current Description
# 0      AR             scattered clouds
# 1      US                    clear sky
# 2      BR                    clear sky
# 3      BR                    clear sky
# 4      PF                   few clouds
# 5      RU              overcast clouds
# 6      TO  light intensity shower rain
# 7      RU             scattered clouds
# 8      US                    clear sky
# 9      GL             scattered clouds

# %%
#rearrange column order
city_data_df=city_data_df[["City", "Country","Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Ushuaia      AR -54.8000  -68.3000     60.46        67          40
# 1     Albany      US  42.6001  -73.9662     21.31        76          10
# 2     Castro      BR -24.7911  -50.0119     61.56        84           2
# 3    Itarema      BR  -2.9248  -39.9167     78.80        78           2
# 4     Atuona      PF  -9.8000 -139.0333     78.80        77          12
# 5   Dvinskoy      RU  62.1535   45.1175     -2.63       100          97
# 6      Vaini      TO -21.2000 -175.2000     75.36       100         100
# 7      Pevek      RU  69.7008  170.3133    -23.37        98          27
# 8  Jamestown      US  42.0970  -79.2353     29.79        45           0
# 9    Qaanaaq      GL  77.4840  -69.3632    -11.67        59          29
#
#    Wind Speed          Current Description
# 0       14.97             scattered clouds
# 1        4.18                    clear sky
# 2        2.10                    clear sky
# 3       11.07                    clear sky
# 4       17.09                   few clouds
# 5        3.91              overcast clouds
# 6        4.61  light intensity shower rain
# 7        0.92             scattered clouds
# 8       10.36                    clear sky
# 9        7.25             scattered clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
